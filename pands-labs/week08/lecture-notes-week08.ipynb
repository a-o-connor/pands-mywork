# %% [markdown]
# # Numpy
# ### Messing around with Numpy
# Resources:\
# [Real Python: What is Numpy?](https://realpython.com/tutorials/numpy/)\
# [W3 Schools Numpy Tutorial ](https://www.w3schools.com/python/numpy/numpy_intro.asp)
# ****

# %% [markdown]
# #### Import libraries
# *******

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
np.array([1,2,3,4,5])
# Out:
# array([1, 2, 3, 4, 5])

# %%
type(np.array([1,2,3,4]))
# Out:
# numpy.ndarray

# %%
np.array([1,2,3,4]) + 3
# Out:
# array([4, 5, 6, 7])

# %%
np.random.normal()
# Out:
# -1.108636837172426

# %% [markdown]
# # Plotting and Matplotlib
# ### Messing around with Matplotlib
# In these lectures, we'll be using stateful approach not the object oriented (stateless, recommended in Ian's lecture) approach.
# *********

# %%
xpoints = np.array(object = range(1,100))
ypoints = xpoints*xpoints
plt.plot(xpoints, ypoints)

# %%
normal_dist = np.random.standard_normal(size = 100)
plt.hist(normal_dist)
# Out:
# (array([ 2.,  3., 14., 12., 17., 16., 17., 10.,  6.,  3.]),
#  array([-2.57068461, -2.06921814, -1.56775166, -1.06628519, -0.56481872,
#         -0.06335224,  0.43811423,  0.9395807 ,  1.44104718,  1.94251365,
#          2.44398012]),
#  <BarContainer object of 10 artists>)

# %%
#Pie chart!
fruit = np.array(["apples","oranges","bananas"])
numbers = np.array([45,66,78])

plt.pie(numbers, labels = fruit)
# Out:
# ([<matplotlib.patches.Wedge at 0x155834560d0>,
# ...
#  [Text(0.8063570573449376, 0.7481900133455492, 'apples'),
#   Text(-0.9386199885485602, 0.5735786930292136, 'oranges'),
#   Text(0.29792459678724875, -1.0588866486216337, 'bananas')])
